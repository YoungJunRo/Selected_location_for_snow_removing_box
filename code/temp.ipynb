# %%
import googlemaps
import pandas as pd
from pyproj import Proj, transform

people=pd.read_csv('../data/org/LOCAL_PEOPLE_GU_2021.csv',encoding='cp949',index_col=False)
map_code=pd.read_csv('../data/법정동.csv',encoding='cp949',index_col=False)

people_data = people.drop(labels = ['기준일ID','시간대구분'], axis=1)
map_code_data=map_code.drop_duplicates('시군구코드')

df=pd.merge(people_data, map_code_data, left_on = '자치구코드', right_on = '시군구코드')
df_data=df.drop(['시군구코드'],axis=1)

data=pd.pivot_table(df_data, index = ['자치구코드','시군구명'], aggfunc = 'sum')
data.to_csv('../data/2020.csv', encoding="cp949")

# %%
data = pd.read_csv('../data/org/행정안전부_급경사지 현황_20211231.csv', encoding='cp949')
data = data[data['시군구'] == '은평구']

# %%
data
# Out:
#             관리번호              급경사지명        시행청명    관리주체구분     시도  시군구  \
# 4199  1138000043    불광사(북한65-00-01)  북한산국립공원사무소    국립공원공단  서울특별시  은평구
# 4200  1138000002               인공비탈        공공기관  지자체(시군구)  서울특별시  은평구
# 4201  1138000011               인공비탈        은평구청  지자체(시군구)  서울특별시  은평구
# 4202  1138000041  삼천사계곡(북한59-01-01)  북한산국립공원사무소    국립공원공단  서울특별시  은평구
# 4203  1138000042  삼천사계곡(북한58-00-02)  북한산국립공원사무소    국립공원공단  서울특별시  은평구
# 4204  1138000044   산성지구(북한51-00-01)  북한산국립공원사무소    국립공원공단  서울특별시  은평구
# 4205  1138000040   산성지구(북한57-00-01)  북한산국립공원사무소    국립공원공단  서울특별시  은평구
# 4206  1138000045   산성지구(북한51-00-02)  북한산국립공원사무소    국립공원공단  서울특별시  은평구
# 4207  1138000046   산성지구(북한57-01-01)  북한산국립공원사무소    국립공원공단  서울특별시  은평구
# 4208  1138000047   산성지구(북한58-00-01)  북한산국립공원사무소    국립공원공단  서울특별시  은평구
#
#              상세주소 도로명상세주소 산주소여부    주지번  부지번
# 4199          NaN     NaN     Y   42.0    1
# 4200          NaN     NaN     N  226.0    2
# 4201     은평구민체육센터     NaN   NaN  362.0    0
# 4202   삼천사하단~응봉방면     NaN     Y   34.0  NaN
# 4203    삼천사하단 미타교     NaN     Y   34.0  NaN
# 4204   북한산성분소~역사관     NaN   NaN  259.0    8
# 4205  백화사~가사당암문방면     NaN     Y   25.0  NaN
# 4206   북한산성분소~역사관     NaN   NaN  259.0  NaN
# 4207    백화사~가사당암문     NaN     Y   25.0  NaN
# 4208  삼천탐방지원센터 상단     NaN     Y   32.0  NaN
